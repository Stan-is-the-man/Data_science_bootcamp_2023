# %%
import pandas as pd

# %%
df_laptops = pd.read_csv('laptop_price.csv', encoding='unicode_escape')

# encoding='unicode_escape' - when problem with UTF-8 unicode !!!!!!

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
df_laptops[df_laptops['Company'] == 'Apple']
# Out:
#       laptop_ID Company      Product   TypeName  Inches
# 0             1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1             2   Apple  Macbook Air  Ultrabook    13.3
# 3             4   Apple  MacBook Pro  Ultrabook    15.4
# 4             5   Apple  MacBook Pro  Ultrabook    13.3
# 6             7   Apple  MacBook Pro  Ultrabook    15.4
# 7             8   Apple  Macbook Air  Ultrabook    13.3
# 12           13   Apple  MacBook Pro  Ultrabook    15.4
# 14           15   Apple  MacBook 12"  Ultrabook    12.0
# 15           16   Apple  MacBook Pro  Ultrabook    13.3
# 17           18   Apple  MacBook Pro  Ultrabook    15.4
# 26           27   Apple  MacBook Air  Ultrabook    13.3
# 34           35   Apple  MacBook Air  Ultrabook    13.3
# 45           46   Apple  MacBook Pro  Ultrabook    13.3
# 81           83   Apple  MacBook 12"  Ultrabook    12.0
# 249         254   Apple  MacBook Pro  Ultrabook    13.3
# 270         275   Apple  MacBook Pro  Ultrabook    13.3
# ...

# %%
df_laptops[df_laptops['Company'] == 'Apple'].value_counts('Company')
# Out:
# Company
# Apple    21
# Name: count, dtype: int64

# %%
df_laptops[df_laptops['Inches'] == 13.3]
# Out:
#       laptop_ID Company               Product            TypeName  Inches
# 0             1   Apple           MacBook Pro           Ultrabook    13.3  \
# 1             2   Apple           Macbook Air           Ultrabook    13.3
# 4             5   Apple           MacBook Pro           Ultrabook    13.3
# 7             8   Apple           Macbook Air           Ultrabook    13.3
# 15           16   Apple           MacBook Pro           Ultrabook    13.3
# ...         ...     ...                   ...                 ...     ...
# 1271       1289  Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1275       1293    Asus  ZenBook UX305CA-UBM1           Ultrabook    13.3
# 1285       1303  Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1289       1307    Asus  ZenBook UX305CA-UBM1           Ultrabook    13.3
# 1299       1317  Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                         Cpu
# ...

# %%
df_laptops[df_laptops['Company'] != 'HP']
# Out:
#       laptop_ID Company                                    Product
# 0             1   Apple                                MacBook Pro  \
# 1             2   Apple                                Macbook Air
# 3             4   Apple                                MacBook Pro
# 4             5   Apple                                MacBook Pro
# 5             6    Acer                                   Aspire 3
# ...         ...     ...                                        ...
# 1297       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       1316  Lenovo                             Yoga 500-14ISK
# 1299       1317  Lenovo                             Yoga 900-13ISK
# 1300       1318  Lenovo                         IdeaPad 100S-14IBR
# 1302       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
df_laptops[df_laptops['Company'] != 'HP'].value_counts('Company')
# Out:
# Company
# Lenovo       297
# Dell         297
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df_laptops[df_laptops['Price_euros'] > 1200]
# Out:
#       laptop_ID Company            Product            TypeName  Inches
# 0             1   Apple        MacBook Pro           Ultrabook    13.3  \
# 3             4   Apple        MacBook Pro           Ultrabook    15.4
# 4             5   Apple        MacBook Pro           Ultrabook    13.3
# 6             7   Apple        MacBook Pro           Ultrabook    15.4
# 8             9    Asus    ZenBook UX430UN           Ultrabook    14.0
# ...         ...     ...                ...                 ...     ...
# 1256       1274    Asus  Rog G752VT-GC073T              Gaming    17.3
# 1259       1277     MSI        GE62 Apache              Gaming    15.6
# 1271       1289  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1285       1303  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1299       1317  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu
# ...

# %%
df_laptops[df_laptops['Price_euros'] > 1200].value_counts('Price_euros')
# Out:
# Price_euros
# 1799.00    14
# 1499.00    14
# 1299.00    11
# 1349.00     9
# 1399.00     9
#            ..
# 1673.00     1
# 1679.00     1
# 1680.00     1
# 1686.64     1
# 6099.00     1
# Name: count, Length: 311, dtype: int64

# %%
import numpy as np

df_laptops['Price Tier'] = np.where(df_laptops['Price_euros'] > 2000, 'Expensive', 'Cheap')
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
df_laptops['Ram Tier'] = np.where(df_laptops['Ram'] == '16GB', 'ENOUGH RAM', 'LOW RAM')

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
df_laptops[df_laptops['Ram Tier'] == 'ENOUGH RAM']
# Out:
#       laptop_ID Company            Product            TypeName  Inches
# 3             4   Apple        MacBook Pro           Ultrabook    15.4  \
# 6             7   Apple        MacBook Pro           Ultrabook    15.4
# 8             9    Asus    ZenBook UX430UN           Ultrabook    14.0
# 12           13   Apple        MacBook Pro           Ultrabook    15.4
# 17           18   Apple        MacBook Pro           Ultrabook    15.4
# ...         ...     ...                ...                 ...     ...
# 1247       1265    Asus        Rog GL502VS              Gaming    15.6
# 1256       1274    Asus  Rog G752VT-GC073T              Gaming    17.3
# 1271       1289  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1285       1303  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1299       1317  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu
# ...

# %%
df_laptops[df_laptops['Ram Tier'] == 'ENOUGH RAM'].value_counts('Ram Tier')
# Out:
# Ram Tier
# ENOUGH RAM    200
# Name: count, dtype: int64

# %%
df_laptops.value_counts('Price Tier')
# Out:
# Price Tier
# Cheap        1166
# Expensive     137
# Name: count, dtype: int64

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
df_laptops['Screen Tier'] = np.where(df_laptops['Inches'] > 13.3, 'Big screen', 'Small screen')

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
df_laptops.value_counts('Screen Tier')
# Out:
# Screen Tier
# Big screen      1049
# Small screen     254
# Name: count, dtype: int64

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
df_laptops[(df_laptops['Company'] == 'Apple') & (df_laptops['Price_euros'] > 2000)]
# Out:
#      laptop_ID Company      Product   TypeName  Inches
# 3            4   Apple  MacBook Pro  Ultrabook    15.4  \
# 6            7   Apple  MacBook Pro  Ultrabook    15.4
# 12          13   Apple  MacBook Pro  Ultrabook    15.4
# 17          18   Apple  MacBook Pro  Ultrabook    15.4
# 249        254   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB  \
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 12   IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# 17   IPS Panel Retina Display 2880x1800  Intel Core i7 2.9GHz  16GB
# 249  IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
#
#                   Memory                           Gpu     OpSys  Weight
# 3              512GB SSD            AMD Radeon Pro 455     macOS  1.83kg  \
# 6    256GB Flash Storage       Intel Iris Pro Graphics  Mac OS X  2.04kg
# ...

# %%
df_laptops[
    ((df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell')) & (df_laptops['Price_euros'] > 2000)]
# Out:
#       laptop_ID Company          Product            TypeName  Inches
# 3             4   Apple      MacBook Pro           Ultrabook    15.4  \
# 6             7   Apple      MacBook Pro           Ultrabook    15.4
# 12           13   Apple      MacBook Pro           Ultrabook    15.4
# 17           18   Apple      MacBook Pro           Ultrabook    15.4
# 186         190    Dell           XPS 15            Notebook    15.6
# 204         208    Dell   Precision 7520         Workstation    15.6
# 224         229    Dell     Alienware 17              Gaming    17.3
# 249         254   Apple      MacBook Pro           Ultrabook    13.3
# 297         302    Dell   Precision 7720         Workstation    17.3
# 311         316    Dell           XPS 13           Ultrabook    13.3
# 329         335    Dell           XPS 15            Notebook    15.6
# 350         356    Dell           XPS 15            Notebook    15.6
# 388         394    Dell   Precision 5520         Workstation    15.6
# ...

# %%
df_laptops[((df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell')) & (
        df_laptops['Price_euros'] > 2000)].value_counts('Company')
# Out:
# Company
# Dell     34
# Apple     5
# Name: count, dtype: int64

# %%
df_laptops[((df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell')) & (
        df_laptops['Price_euros'] > 2000)].value_counts('Price_euros')
# Out:
# Price_euros
# 2013.10    1
# 2868.99    1
# 2712.00    1
# 2758.00    1
# 2774.63    1
# 2799.00    1
# 2800.00    1
# 2813.75    1
# 2858.00    1
# 2884.86    1
# 2680.00    1
# 3012.77    1
# 3055.00    1
# 3072.89    1
# 3147.37    1
# 3149.00    1
# 3154.00    1
# 3588.80    1
# 2699.00    1
# 2639.00    1
# 2027.42    1
# 2254.00    1
# 2040.00    1
# 2046.00    1
# 2051.00    1
# 2135.00    1
# 2139.97    1
# 2240.00    1
# 2250.68    1
# 2338.00    1
# 2537.45    1
# 2397.00    1
# 2399.00    1
# 2408.00    1
# 2439.97    1
# 2456.34    1
# 2499.00    1
# 2505.02    1
# 3659.40    1
# Name: count, dtype: int64

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
conditions = [
    df_laptops['Inches'] > 16,
    (df_laptops['Inches'] > 14) & (df_laptops['Inches'] <= 16),
    (df_laptops['Inches'] > 12) & (df_laptops['Inches'] <= 14),
    df_laptops['Inches'] <= 12
]
values = ['Too big', 'Big', 'Small', 'Too small']

df_laptops['Screen size'] = np.select(conditions, values)

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
df_laptops[df_laptops["Company"].isin(['Apple', 'HP'])]
# Out:
#       laptop_ID Company                              Product   TypeName
# 0             1   Apple                          MacBook Pro  Ultrabook  \
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1282       1300      HP                     Stream 11-Y000na    Netbook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1296       1314      HP                     Stream 11-Y000na    Netbook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution
# 0       13.3  IPS Panel Retina Display 2560x1600  \
# ...

# %%
condition1 = df_laptops["TypeName"].isin(['Notebook', 'Ultrabook'])
condition2 = df_laptops["Company"].isin(['Apple', 'HP'])

# %%
df_laptops[condition1 & condition2]
# Out:
#       laptop_ID Company                              Product   TypeName
# 0             1   Apple                          MacBook Pro  Ultrabook  \
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1273       1291      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1280       1298      HP                  Pavilion 15-AW003nv   Notebook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution                         Cpu
# ...

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600  \
# ...

# %%
condition1 = df_laptops['Company'].isin(['Dell', 'HP'])
condition2 = df_laptops['TypeName'].isin(['Ultrabook'])
condition3 = df_laptops['Inches'] <= 13.3
condition4 = df_laptops['Price_euros'] < 1000

# %%
df_laptops[condition1 & condition2 & condition3 & condition4]
# Out:
#       laptop_ID Company        Product   TypeName  Inches
# 19           20    Dell         XPS 13  Ultrabook    13.3  \
# 71           73    Dell  Inspiron 5370  Ultrabook    13.3
# 215         220    Dell  Inspiron 5370  Ultrabook    13.3
# 255         260    Dell    Vostro 5370  Ultrabook    13.3
# 510         517    Dell         XPS 13  Ultrabook    13.3
# 1093       1108    Dell  Inspiron 5370  Ultrabook    13.3
#
#                                ScreenResolution                         Cpu
# 19    IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz  \
# 71                  IPS Panel Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 215                 IPS Panel Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 255                           Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 510   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 7200U 2.5GHz
# 1093                IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
#
# ...

# %%
df_laptops[condition1 & condition2 & condition3 & condition4].value_counts('Company')
# Out:
# Company
# Dell    6
# Name: count, dtype: int64

# %%
duplicate1 = df_laptops.duplicated('laptop_ID')

# %%
df_laptops[duplicate1]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros, Price Tier, Ram Tier, Screen Tier, Screen size]
# Index: []

# %%
duplicate_in_3_columns = df_laptops.duplicated(['Product', 'TypeName', 'Inches'])

# %%
df_laptops[duplicate_in_3_columns]
# Out:
# C:\Users\yomax\AppData\Local\Temp\ipykernel_14324\1058965257.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_laptops[duplicate_in_3_columns]
#       laptop_ID  Company         Product   TypeName  Inches
# 1198       1216     Acer        Aspire 3   Notebook    15.6  \
# 1277       1295     Acer  Aspire ES1-531   Notebook    15.6
# 1291       1309     Acer  Aspire ES1-531   Notebook    15.6
# 769         778     Acer  Aspire A315-31   Notebook    15.6
# 745         753     Acer   Chromebook 14   Notebook    14.0
# ...         ...      ...             ...        ...     ...
# 531         538  Toshiba   Satellite Pro   Notebook    15.6
# 331         337  Toshiba   Satellite Pro   Notebook    15.6
# 307         312  Toshiba   Satellite Pro   Notebook    15.6
# 877         888   Xiaomi     Mi Notebook  Ultrabook    13.3
# 514         521   Xiaomi     Mi Notebook   Notebook    15.6
#
# ...

# %%
duplicate3 = df_laptops.duplicated(["Company",'Inches', 'Cpu','Ram'])

# %%
df_laptops[duplicate3]
# Out:
#       laptop_ID Company                              Product
# 7             8   Apple                          Macbook Air  \
# 15           16   Apple                          MacBook Pro
# 23           24    Dell                        Inspiron 5379
# 25           26    Dell                        Inspiron 3567
# 34           35   Apple                          MacBook Air
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution
# 7              Ultrabook    13.3                                    1440x900  \
# ...

# %%
df_laptops = df_laptops.sort_values(['Company', 'Price_euros'])
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6  \
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
duplicate_filter = df_laptops.duplicated('Company', keep = 'last')

# %%
df_laptops[~duplicate_filter][['Company', 'Price_euros']]
# Out:
#         Company  Price_euros
# 1189       Acer      2599.00
# 17        Apple      2858.00
# 1066       Asus      3975.00
# 421       Chuwi       449.00
# 723        Dell      3659.40
# 623     Fujitsu       799.00
# 437      Google      2199.00
# 749          HP      4389.00
# 214      Huawei      1499.00
# 678          LG      2299.00
# 610      Lenovo      4899.00
# 177         MSI      2799.00
# 580    Mediacom       389.00
# 449   Microsoft      2589.00
# 196       Razer      6099.00
# 874     Samsung      1849.00
# 491     Toshiba      2799.00
# 191        Vero       260.00
# 514      Xiaomi      1399.95

# %%
df_laptops.sort_values(['Company','laptop_ID'],  ascending = False)
# Out:
#       laptop_ID Company                           Product   TypeName  Inches
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3  \
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 1120       1135    Vero  V131 (X5-Z8350/4GB/32GB/FHD/W10)   Notebook    13.3
# ...         ...     ...                               ...        ...     ...
# 51           52    Acer                   Aspire A515-51G   Notebook    15.6
# 43           44    Acer                   Aspire A515-51G   Notebook    15.6
# 36           37    Acer                          Aspire 3   Notebook    15.6
# 9            10    Acer                           Swift 3  Ultrabook    14.0
# 5             6    Acer                          Aspire 3   Notebook    15.6
#
# ...

# %%
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6  \
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
df_laptops.drop_duplicates('Company', ignore_index= True)[['Company', 'Price_euros']]
# Out:
#       Company  Price_euros
# 0        Acer       174.00
# 1       Apple       898.94
# 2        Asus       191.90
# 3       Chuwi       244.99
# 4        Dell       274.90
# 5     Fujitsu       649.00
# 6      Google      1275.00
# 7          HP       209.00
# 8      Huawei      1349.00
# 9          LG      1899.00
# 10     Lenovo       229.00
# 11        MSI       839.00
# 12   Mediacom       239.00
# 13  Microsoft       989.00
# 14      Razer      1029.00
# 15    Samsung       269.00
# 16    Toshiba       447.00
# 17       Vero       196.00
# 18     Xiaomi       935.00
